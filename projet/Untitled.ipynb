# %%
import numpy as np
import pandas as pd

# %%
data = 'data/dpt2016.txt'

pd.read_table(data)
# Out:
#          sexe    preusuel annais  dpt  nombre
# 0           1           A   XXXX   XX      28
# 1           1       AADAM   XXXX   XX      20
# 2           1       AADEL   XXXX   XX      54
# 3           1       AADIL   1983   84       3
# 4           1       AADIL   1992   92       3
# 5           1       AADIL   XXXX   XX     167
# 6           1      AAKASH   XXXX   XX      24
# 7           1       AARON   1962   75       3
# 8           1       AARON   1982   75       3
# 9           1       AARON   1984   75       3
# 10          1       AARON   1985   75       4
# 11          1       AARON   1989   75       3
# 12          1       AARON   1990   69       3
# 13          1       AARON   1990   75       4
# 14          1       AARON   1990   93       4
# 15          1       AARON   1991   75       5
# 16          1       AARON   1992   75       6
# 17          1       AARON   1993   75       5
# 18          1       AARON   1994   75       8
# ...
